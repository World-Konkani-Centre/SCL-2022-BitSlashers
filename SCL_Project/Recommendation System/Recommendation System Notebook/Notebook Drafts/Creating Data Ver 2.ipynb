# %%
import pandas as pd
import numpy as np

# %%
# %%bash
# git clone https://github.com/kptriescoding/farmer-app-datasets
# Out:
# Cloning into 'farmer-app-datasets'...

# %%
df_name=pd.read_csv("/content/farmer-app-datasets/Recommendation System/ExportCSV.csv")
df_farmer=pd.read_csv("/content/farmer-app-datasets/Datasets/farmers.csv")["Bates Double Glazing Ltd"]
df_name
# Out:
#     FirstName LastName
# 0        Hayden Ripley
# 1           Lucy Lakey
# 2          Daphne Long
# 3         Percy Torres
# 4    Vanessa Alldridge
# ..                 ...
# 495       Taylor Vince
# 496     Bryce Clarkson
# 497        Gina Watson
# 498     Martin Poulton
# 499      Johnny Palmer
#
# [500 rows x 1 columns]

# %%
d_farmer=[]
for i in range(1,400):
  d_farmer.append(df_farmer.loc[np.random.randint(0,4)])
d_farmer
# Out:
# ['Oakes Workshops Ltd',
#  'Tilly Beverages Ltd',
#  'Tilly Beverages Ltd',
#  'Peabody Workwear Ltd',
#  'Riverside Circuitry Ltd',
#  'Tilly Beverages Ltd',
#  'Tilly Beverages Ltd',
#  'Riverside Circuitry Ltd',
#  'Oakes Workshops Ltd',
#  'Tilly Beverages Ltd',
#  'Tilly Beverages Ltd',
#  'Peabody Workwear Ltd',
#  'Peabody Workwear Ltd',
#  'Tilly Beverages Ltd',
#  'Peabody Workwear Ltd',
#  'Oakes Workshops Ltd',
#  'Tilly Beverages Ltd',
#  'Oakes Workshops Ltd',
#  'Oakes Workshops Ltd',
#  'Riverside Circuitry Ltd',
#  'Riverside Circuitry Ltd',
#  'Riverside Circuitry Ltd',
#  'Tilly Beverages Ltd',
#  'Tilly Beverages Ltd',
#  'Tilly Beverages Ltd',
#  'Oakes Workshops Ltd',
#  'Tilly Beverages Ltd',
#  'Tilly Beverages Ltd',
#  'Riverside Circuitry Ltd',
#  'Oakes Workshops Ltd',
#  'Riverside Circuitry Ltd',
#  'Peabody Workwear Ltd',
#  'Oakes Workshops Ltd',
#  'Peabody Workwear Ltd',
#  'Peabody Workwear Ltd',
#  'Oakes Workshops Ltd',
#  'Tilly Beverages Ltd',
#  'Tilly Beverages Ltd',
#  'Riverside Circuitry Ltd',
#  'Oakes Workshops Ltd',
#  'Riverside Circuitry Ltd',
#  'Tilly Beverages Ltd',
#  'Riverside Circuitry Ltd',
#  'Oakes Workshops Ltd',
#  'Oakes Workshops Ltd',
#  'Oakes Workshops Ltd',
#  'Peabody Workwear Ltd',
#  'Tilly Beverages Ltd',
#  'Riverside Circuitry Ltd',
#  'Oakes Workshops Ltd',
#  'Riverside Circuitry Ltd',
#  'Peabody Workwear Ltd',
#  'Riverside Circuitry Ltd',
#  'Oakes Workshops Ltd',
#  'Tilly Beverages Ltd',
#  'Tilly Beverages Ltd',
#  'Peabody Workwear Ltd',
#  'Tilly Beverages Ltd',
#  'Tilly Beverages Ltd',
#  'Peabody Workwear Ltd',
#  'Tilly Beverages Ltd',
#  'Peabody Workwear Ltd',
#  'Oakes Workshops Ltd',
#  'Riverside Circuitry Ltd',
#  'Peabody Workwear Ltd',
#  'Tilly Beverages Ltd',
#  'Riverside Circuitry Ltd',
#  'Tilly Beverages Ltd',
#  'Riverside Circuitry Ltd',
#  'Peabody Workwear Ltd',
#  'Riverside Circuitry Ltd',
#  'Peabody Workwear Ltd',
#  'Oakes Workshops Ltd',
#  'Peabody Workwear Ltd',
#  'Oakes Workshops Ltd',
#  'Riverside Circuitry Ltd',
#  'Riverside Circuitry Ltd',
#  'Peabody Workwear Ltd',
#  'Peabody Workwear Ltd',
#  'Tilly Beverages Ltd',
#  'Oakes Workshops Ltd',
#  'Oakes Workshops Ltd',
#  'Peabody Workwear Ltd',
#  'Tilly Beverages Ltd',
#  'Oakes Workshops Ltd',
#  'Riverside Circuitry Ltd',
#  'Peabody Workwear Ltd',
#  'Riverside Circuitry Ltd',
#  'Tilly Beverages Ltd',
#  'Tilly Beverages Ltd',
#  'Oakes Workshops Ltd',
#  'Peabody Workwear Ltd',
#  'Peabody Workwear Ltd',
#  'Oakes Workshops Ltd',
#  'Oakes Workshops Ltd',
#  'Tilly Beverages Ltd',
#  'Riverside Circuitry Ltd',
#  'Riverside Circuitry Ltd',
#  'Peabody Workwear Ltd',
#  'Peabody Workwear Ltd',
#  'Riverside Circuitry Ltd',
#  'Riverside Circuitry Ltd',
#  'Peabody Workwear Ltd',
#  'Tilly Beverages Ltd',
#  'Tilly Beverages Ltd',
#  'Riverside Circuitry Ltd',
#  'Riverside Circuitry Ltd',
#  'Oakes Workshops Ltd',
#  'Oakes Workshops Ltd',
#  'Tilly Beverages Ltd',
#  'Tilly Beverages Ltd',
#  'Oakes Workshops Ltd',
#  'Oakes Workshops Ltd',
#  'Tilly Beverages Ltd',
#  'Tilly Beverages Ltd',
#  'Oakes Workshops Ltd',
#  'Peabody Workwear Ltd',
#  'Peabody Workwear Ltd',
#  'Riverside Circuitry Ltd',
#  'Oakes Workshops Ltd',
#  'Oakes Workshops Ltd',
#  'Oakes Workshops Ltd',
#  'Riverside Circuitry Ltd',
#  'Tilly Beverages Ltd',
#  'Riverside Circuitry Ltd',
#  'Oakes Workshops Ltd',
#  'Peabody Workwear Ltd',
#  'Peabody Workwear Ltd',
#  'Riverside Circuitry Ltd',
#  'Riverside Circuitry Ltd',
#  'Riverside Circuitry Ltd',
#  'Oakes Workshops Ltd',
#  'Tilly Beverages Ltd',
#  'Tilly Beverages Ltd',
#  'Tilly Beverages Ltd',
#  'Riverside Circuitry Ltd',
#  'Riverside Circuitry Ltd',
#  'Peabody Workwear Ltd',
#  'Riverside Circuitry Ltd',
#  'Peabody Workwear Ltd',
#  'Oakes Workshops Ltd',
#  'Riverside Circuitry Ltd',
#  'Oakes Workshops Ltd',
#  'Tilly Beverages Ltd',
#  'Riverside Circuitry Ltd',
#  'Oakes Workshops Ltd',
#  'Riverside Circuitry Ltd',
#  'Riverside Circuitry Ltd',
#  'Riverside Circuitry Ltd',
#  'Riverside Circuitry Ltd',
#  'Tilly Beverages Ltd',
#  'Peabody Workwear Ltd',
#  'Peabody Workwear Ltd',
#  'Tilly Beverages Ltd',
#  'Tilly Beverages Ltd',
#  'Peabody Workwear Ltd',
#  'Oakes Workshops Ltd',
#  'Tilly Beverages Ltd',
#  'Tilly Beverages Ltd',
#  'Peabody Workwear Ltd',
#  'Tilly Beverages Ltd',
#  'Riverside Circuitry Ltd',
#  'Oakes Workshops Ltd',
#  'Oakes Workshops Ltd',
#  'Tilly Beverages Ltd',
#  'Riverside Circuitry Ltd',
#  'Tilly Beverages Ltd',
#  'Tilly Beverages Ltd',
#  'Peabody Workwear Ltd',
#  'Peabody Workwear Ltd',
#  'Oakes Workshops Ltd',
#  'Oakes Workshops Ltd',
#  'Peabody Workwear Ltd',
#  'Tilly Beverages Ltd',
#  'Riverside Circuitry Ltd',
#  'Tilly Beverages Ltd',
#  'Peabody Workwear Ltd',
#  'Tilly Beverages Ltd',
#  'Tilly Beverages Ltd',
#  'Peabody Workwear Ltd',
#  'Peabody Workwear Ltd',
#  'Riverside Circuitry Ltd',
#  'Tilly Beverages Ltd',
#  'Riverside Circuitry Ltd',
#  'Peabody Workwear Ltd',
#  'Riverside Circuitry Ltd',
#  'Peabody Workwear Ltd',
#  'Peabody Workwear Ltd',
#  'Peabody Workwear Ltd',
#  'Tilly Beverages Ltd',
#  'Riverside Circuitry Ltd',
#  'Peabody Workwear Ltd',
#  'Tilly Beverages Ltd',
#  'Peabody Workwear Ltd',
#  'Peabody Workwear Ltd',
#  'Riverside Circuitry Ltd',
#  'Riverside Circuitry Ltd',
#  'Riverside Circuitry Ltd',
#  'Oakes Workshops Ltd',
#  'Peabody Workwear Ltd',
#  'Riverside Circuitry Ltd',
#  'Oakes Workshops Ltd',
#  'Peabody Workwear Ltd',
#  'Tilly Beverages Ltd',
#  'Peabody Workwear Ltd',
#  'Riverside Circuitry Ltd',
#  'Oakes Workshops Ltd',
#  'Riverside Circuitry Ltd',
#  'Oakes Workshops Ltd',
#  'Oakes Workshops Ltd',
#  'Oakes Workshops Ltd',
#  'Peabody Workwear Ltd',
#  'Peabody Workwear Ltd',
#  'Oakes Workshops Ltd',
#  'Peabody Workwear Ltd',
#  'Riverside Circuitry Ltd',
#  'Riverside Circuitry Ltd',
#  'Riverside Circuitry Ltd',
#  'Tilly Beverages Ltd',
#  'Oakes Workshops Ltd',
#  'Riverside Circuitry Ltd',
#  'Oakes Workshops Ltd',
#  'Riverside Circuitry Ltd',
#  'Tilly Beverages Ltd',
#  'Peabody Workwear Ltd',
#  'Tilly Beverages Ltd',
#  'Peabody Workwear Ltd',
#  'Peabody Workwear Ltd',
#  'Oakes Workshops Ltd',
#  'Peabody Workwear Ltd',
#  'Peabody Workwear Ltd',
#  'Tilly Beverages Ltd',
#  'Riverside Circuitry Ltd',
#  'Tilly Beverages Ltd',
#  'Riverside Circuitry Ltd',
#  'Peabody Workwear Ltd',
#  'Oakes Workshops Ltd',
#  'Tilly Beverages Ltd',
#  'Peabody Workwear Ltd',
#  'Peabody Workwear Ltd',
#  'Tilly Beverages Ltd',
#  'Peabody Workwear Ltd',
#  'Riverside Circuitry Ltd',
#  'Tilly Beverages Ltd',
#  'Tilly Beverages Ltd',
#  'Oakes Workshops Ltd',
#  'Tilly Beverages Ltd',
#  'Tilly Beverages Ltd',
#  'Peabody Workwear Ltd',
#  'Tilly Beverages Ltd',
#  'Riverside Circuitry Ltd',
#  'Peabody Workwear Ltd',
#  'Tilly Beverages Ltd',
#  'Tilly Beverages Ltd',
#  'Tilly Beverages Ltd',
#  'Riverside Circuitry Ltd',
#  'Oakes Workshops Ltd',
#  'Peabody Workwear Ltd',
#  'Oakes Workshops Ltd',
#  'Riverside Circuitry Ltd',
#  'Peabody Workwear Ltd',
#  'Oakes Workshops Ltd',
#  'Tilly Beverages Ltd',
#  'Peabody Workwear Ltd',
#  'Peabody Workwear Ltd',
#  'Tilly Beverages Ltd',
#  'Riverside Circuitry Ltd',
#  'Riverside Circuitry Ltd',
#  'Tilly Beverages Ltd',
#  'Tilly Beverages Ltd',
#  'Tilly Beverages Ltd',
#  'Tilly Beverages Ltd',
#  'Tilly Beverages Ltd',
#  'Tilly Beverages Ltd',
#  'Peabody Workwear Ltd',
#  'Oakes Workshops Ltd',
#  'Peabody Workwear Ltd',
#  'Tilly Beverages Ltd',
#  'Oakes Workshops Ltd',
#  'Tilly Beverages Ltd',
#  'Riverside Circuitry Ltd',
#  'Peabody Workwear Ltd',
#  'Tilly Beverages Ltd',
#  'Riverside Circuitry Ltd',
#  'Oakes Workshops Ltd',
#  'Oakes Workshops Ltd',
#  'Peabody Workwear Ltd',
#  'Tilly Beverages Ltd',
#  'Tilly Beverages Ltd',
#  'Peabody Workwear Ltd',
#  'Peabody Workwear Ltd',
#  'Peabody Workwear Ltd',
#  'Tilly Beverages Ltd',
#  'Riverside Circuitry Ltd',
#  'Riverside Circuitry Ltd',
#  'Oakes Workshops Ltd',
#  'Peabody Workwear Ltd',
#  'Riverside Circuitry Ltd',
#  'Peabody Workwear Ltd',
#  'Peabody Workwear Ltd',
#  'Tilly Beverages Ltd',
#  'Riverside Circuitry Ltd',
#  'Tilly Beverages Ltd',
#  'Oakes Workshops Ltd',
#  'Oakes Workshops Ltd',
#  'Riverside Circuitry Ltd',
#  'Oakes Workshops Ltd',
#  'Oakes Workshops Ltd',
#  'Tilly Beverages Ltd',
#  'Tilly Beverages Ltd',
#  'Riverside Circuitry Ltd',
#  'Oakes Workshops Ltd',
#  'Tilly Beverages Ltd',
#  'Oakes Workshops Ltd',
#  'Riverside Circuitry Ltd',
#  'Oakes Workshops Ltd',
#  'Tilly Beverages Ltd',
#  'Riverside Circuitry Ltd',
#  'Tilly Beverages Ltd',
#  'Peabody Workwear Ltd',
#  'Tilly Beverages Ltd',
#  'Peabody Workwear Ltd',
#  'Peabody Workwear Ltd',
#  'Riverside Circuitry Ltd',
#  'Peabody Workwear Ltd',
#  'Peabody Workwear Ltd',
#  'Tilly Beverages Ltd',
#  'Tilly Beverages Ltd',
#  'Riverside Circuitry Ltd',
#  'Tilly Beverages Ltd',
#  'Tilly Beverages Ltd',
#  'Oakes Workshops Ltd',
#  'Peabody Workwear Ltd',
#  'Oakes Workshops Ltd',
#  'Oakes Workshops Ltd',
#  'Oakes Workshops Ltd',
#  'Tilly Beverages Ltd',
#  'Oakes Workshops Ltd',
#  'Peabody Workwear Ltd',
#  'Oakes Workshops Ltd',
#  'Riverside Circuitry Ltd',
#  'Oakes Workshops Ltd',
#  'Peabody Workwear Ltd',
#  'Peabody Workwear Ltd',
#  'Riverside Circuitry Ltd',
#  'Tilly Beverages Ltd',
#  'Riverside Circuitry Ltd',
#  'Peabody Workwear Ltd',
#  'Oakes Workshops Ltd',
#  'Oakes Workshops Ltd',
#  'Tilly Beverages Ltd',
#  'Riverside Circuitry Ltd',
#  'Riverside Circuitry Ltd',
#  'Oakes Workshops Ltd',
#  'Peabody Workwear Ltd',
#  'Tilly Beverages Ltd',
#  'Oakes Workshops Ltd',
#  'Oakes Workshops Ltd',
#  'Tilly Beverages Ltd',
#  'Tilly Beverages Ltd',
#  'Peabody Workwear Ltd',
#  'Peabody Workwear Ltd',
#  'Riverside Circuitry Ltd',
#  'Riverside Circuitry Ltd',
#  'Peabody Workwear Ltd',
#  'Peabody Workwear Ltd',
#  'Tilly Beverages Ltd',
#  'Oakes Workshops Ltd',
#  'Riverside Circuitry Ltd',
#  'Tilly Beverages Ltd',
#  'Oakes Workshops Ltd',
#  'Peabody Workwear Ltd',
#  'Riverside Circuitry Ltd',
#  'Oakes Workshops Ltd',
#  'Tilly Beverages Ltd',
#  'Peabody Workwear Ltd',
#  'Tilly Beverages Ltd',
#  'Peabody Workwear Ltd',
#  'Tilly Beverages Ltd',
#  'Riverside Circuitry Ltd',
#  'Riverside Circuitry Ltd',
#  'Peabody Workwear Ltd',
#  'Tilly Beverages Ltd',
#  'Peabody Workwear Ltd',
#  'Riverside Circuitry Ltd',
#  'Tilly Beverages Ltd',
#  'Peabody Workwear Ltd',
#  'Oakes Workshops Ltd',
#  'Riverside Circuitry Ltd',
#  'Oakes Workshops Ltd',
#  'Tilly Beverages Ltd',
#  'Tilly Beverages Ltd',
#  'Tilly Beverages Ltd',
#  'Tilly Beverages Ltd',
#  'Tilly Beverages Ltd',
#  'Oakes Workshops Ltd',
#  'Oakes Workshops Ltd',
#  'Oakes Workshops Ltd',
#  'Oakes Workshops Ltd']

# %%
d_frequency=np.random.randint(1,7,400)
d_na=np.full(shape=100,fill_value=0)
d_f=np.concatenate([d_frequency,d_na],axis=None)
df=pd.DataFrame(d_f,columns=["Wheat Freqeuncy"]);


d_quan=np.random.randint(1,1000,400)
d_q=np.concatenate([d_quan,d_na],axis=None)
df_q=pd.DataFrame(d_q,columns=["Wheat Quantity"])


np.random.shuffle(d_farmer)
d_ex=np.full(shape=100,fill_value="NA")
df_f=pd.DataFrame(d_farmer,columns=["Wheat Seller"])



df_full=pd.concat([df,df_q,df_f],axis=1)
df_full_wheat=df_full.sample(frac=1)
print(df_full_wheat)
# Out:
#      Wheat Freqeuncy  Wheat Quantity             Wheat Seller
# 290                1             771  Riverside Circuitry Ltd
# 89                 2             556      Oakes Workshops Ltd
# 392                5             619      Tilly Beverages Ltd
# 285                4             988  Riverside Circuitry Ltd
# 233                5             661      Tilly Beverages Ltd
# ..               ...             ...                      ...
# 413                0               0                      NaN
# 80                 6             368      Tilly Beverages Ltd
# 136                1             534  Riverside Circuitry Ltd
# 259                2             237      Tilly Beverages Ltd
# 318                2             542      Tilly Beverages Ltd
#
# [500 rows x 3 columns]

# %%
d_frequency=np.random.randint(1,7,400)
d_na=np.full(shape=100,fill_value=0)
d_f=np.concatenate([d_frequency,d_na],axis=None)
df=pd.DataFrame(d_f,columns=["Rubber Freqeuncy"]);


d_quan=np.random.randint(1,1000,400)
d_q=np.concatenate([d_quan,d_na],axis=None)
df_q=pd.DataFrame(d_q,columns=["Rubber Quantity"])


np.random.shuffle(d_farmer)
d_ex=np.full(shape=100,fill_value="NA")
df_f=pd.DataFrame(d_farmer,columns=["Rubber Seller"])



df_full=pd.concat([df,df_q,df_f],axis=1)
df_full_rubber=df_full.sample(frac=1)
print(df_full_rubber)
# Out:
#      Rubber Freqeuncy  Rubber Quantity         Rubber Seller
# 304                 1              589  Peabody Workwear Ltd
# 426                 0                0                   NaN
# 392                 4              492   Tilly Beverages Ltd
# 369                 6              477   Oakes Workshops Ltd
# 409                 0                0                   NaN
# ..                ...              ...                   ...
# 221                 2              466   Tilly Beverages Ltd
# 233                 2              449  Peabody Workwear Ltd
# 210                 4              475   Tilly Beverages Ltd
# 345                 1              962   Oakes Workshops Ltd
# 193                 3               38   Oakes Workshops Ltd
#
# [500 rows x 3 columns]

# %%
d_frequency=np.random.randint(1,7,400)
d_na=np.full(shape=100,fill_value=0)
d_f=np.concatenate([d_frequency,d_na],axis=None)
df=pd.DataFrame(d_f,columns=["Maize Freqeuncy"]);


d_quan=np.random.randint(1,1000,400)
d_q=np.concatenate([d_quan,d_na],axis=None)
df_q=pd.DataFrame(d_q,columns=["Maize Quantity"])


np.random.shuffle(d_farmer)
d_ex=np.full(shape=100,fill_value="NA")
df_f=pd.DataFrame(d_farmer,columns=["Maize Seller"])



df_full=pd.concat([df,df_q,df_f],axis=1)
df_full_maize=df_full.sample(frac=1)
print(df_full_maize)
# Out:
#      Maize Freqeuncy  Maize Quantity             Maize Seller
# 77                 4             826  Riverside Circuitry Ltd
# 139                3             760      Tilly Beverages Ltd
# 163                1             534      Tilly Beverages Ltd
# 446                0               0                      NaN
# 367                4             161      Oakes Workshops Ltd
# ..               ...             ...                      ...
# 120                6             275     Peabody Workwear Ltd
# 86                 4             589  Riverside Circuitry Ltd
# 108                2             506  Riverside Circuitry Ltd
# 196                6             952     Peabody Workwear Ltd
# 13                 6             352      Oakes Workshops Ltd
#
# [500 rows x 3 columns]

# %%
d_frequency=np.random.randint(1,7,400)
d_na=np.full(shape=100,fill_value=0)
d_f=np.concatenate([d_frequency,d_na],axis=None)
df=pd.DataFrame(d_f,columns=["Barley Freqeuncy"]);


d_quan=np.random.randint(1,1000,400)
d_q=np.concatenate([d_quan,d_na],axis=None)
df_q=pd.DataFrame(d_q,columns=["Barley Quantity"])


np.random.shuffle(d_farmer)
d_ex=np.full(shape=100,fill_value="NA")
df_f=pd.DataFrame(d_farmer,columns=["Barley Seller"])



df_full=pd.concat([df,df_q,df_f],axis=1)
df_full_barley=df_full.sample(frac=1)
print(df_full_barley)
# Out:
#      Barley Freqeuncy  Barley Quantity            Barley Seller
# 97                  1              181     Peabody Workwear Ltd
# 6                   3              882  Riverside Circuitry Ltd
# 443                 0                0                      NaN
# 80                  2               91      Oakes Workshops Ltd
# 471                 0                0                      NaN
# ..                ...              ...                      ...
# 84                  1              399     Peabody Workwear Ltd
# 427                 0                0                      NaN
# 468                 0                0                      NaN
# 386                 4              770  Riverside Circuitry Ltd
# 140                 1              220     Peabody Workwear Ltd
#
# [500 rows x 3 columns]

# %%
d_frequency=np.random.randint(1,7,400)
d_na=np.full(shape=100,fill_value=0)
d_f=np.concatenate([d_frequency,d_na],axis=None)
df=pd.DataFrame(d_f,columns=["Sugercane Freqeuncy"]);


d_quan=np.random.randint(1,1000,400)
d_q=np.concatenate([d_quan,d_na],axis=None)
df_q=pd.DataFrame(d_q,columns=["Sugercane Quantity"])


np.random.shuffle(d_farmer)
d_ex=np.full(shape=100,fill_value="NA")
df_f=pd.DataFrame(d_farmer,columns=["Sugercane Seller"])



df_full=pd.concat([df,df_q,df_f],axis=1)
df_full_sugarcane=df_full.sample(frac=1)
print(df_full_sugarcane)
# Out:
#      Sugercane Freqeuncy  Sugercane Quantity         Sugercane Seller
# 137                    1                   4      Tilly Beverages Ltd
# 381                    1                 410      Tilly Beverages Ltd
# 37                     2                 129  Riverside Circuitry Ltd
# 368                    4                 237     Peabody Workwear Ltd
# 295                    5                 432     Peabody Workwear Ltd
# ..                   ...                 ...                      ...
# 465                    0                   0                      NaN
# 279                    2                 189      Tilly Beverages Ltd
# 192                    6                 297      Oakes Workshops Ltd
# 237                    5                 816     Peabody Workwear Ltd
# 278                    5                 658      Tilly Beverages Ltd
#
# [500 rows x 3 columns]

# %%
d_dist=np.random.randint(1,1000,500)
d_dis=np.concatenate(d_dist,axis=None)
df_dis=pd.DataFrame(d_dis,columns=["Distance"])

# %%
df_full_wheat=df_full_wheat.reset_index();
df_full_rubber=df_full_rubber.reset_index();
df_full_maize=df_full_maize.reset_index();
df_full_sugarcane=df_full_sugarcane.reset_index();
df_full_barley=df_full_barley.reset_index();
df_dis.reset_index()
# Out:
#      index  Distance
# 0        0       666
# 1        1       588
# 2        2       295
# 3        3       718
# 4        4       404
# ..     ...       ...
# 495    495       766
# 496    496       585
# 497    497       986
# 498    498       614
# 499    499       774
#
# [500 rows x 2 columns]

# %%
df=pd.concat([df_name,df_full_wheat,df_full_sugarcane,df_full_rubber,df_full_maize,df_full_barley,df_dis],axis=1);
df.drop(["index"],inplace=True,axis=1)
print(df)
# Out:
#     FirstName LastName  Wheat Freqeuncy  Wheat Quantity  \
# 0        Hayden Ripley                1             771
# 1           Lucy Lakey                2             556
# 2          Daphne Long                5             619
# 3         Percy Torres                4             988
# 4    Vanessa Alldridge                5             661
# ..                 ...              ...             ...
# 495       Taylor Vince                0               0
# 496     Bryce Clarkson                6             368
# 497        Gina Watson                1             534
# 498     Martin Poulton                2             237
# 499      Johnny Palmer                2             542
#
#                 Wheat Seller  Sugercane Freqeuncy  Sugercane Quantity  \
# 0    Riverside Circuitry Ltd                    1                   4
# 1        Oakes Workshops Ltd                    1                 410
# 2        Tilly Beverages Ltd                    2                 129
# 3    Riverside Circuitry Ltd                    4                 237
# 4        Tilly Beverages Ltd                    5                 432
# ..                       ...                  ...                 ...
# 495                      NaN                    0                   0
# 496      Tilly Beverages Ltd                    2                 189
# 497  Riverside Circuitry Ltd                    6                 297
# 498      Tilly Beverages Ltd                    5                 816
# 499      Tilly Beverages Ltd                    5                 658
#
#             Sugercane Seller  Rubber Freqeuncy  Rubber Quantity  \
# 0        Tilly Beverages Ltd                 1              589
# 1        Tilly Beverages Ltd                 0                0
# 2    Riverside Circuitry Ltd                 4              492
# 3       Peabody Workwear Ltd                 6              477
# 4       Peabody Workwear Ltd                 0                0
# ..                       ...               ...              ...
# 495                      NaN                 2              466
# 496      Tilly Beverages Ltd                 2              449
# 497      Oakes Workshops Ltd                 4              475
# 498     Peabody Workwear Ltd                 1              962
# 499      Tilly Beverages Ltd                 3               38
#
#             Rubber Seller  Maize Freqeuncy  Maize Quantity  \
# 0    Peabody Workwear Ltd                4             826
# 1                     NaN                3             760
# 2     Tilly Beverages Ltd                1             534
# 3     Oakes Workshops Ltd                0               0
# 4                     NaN                4             161
# ..                    ...              ...             ...
# 495   Tilly Beverages Ltd                6             275
# 496  Peabody Workwear Ltd                4             589
# 497   Tilly Beverages Ltd                2             506
# 498   Oakes Workshops Ltd                6             952
# 499   Oakes Workshops Ltd                6             352
#
#                 Maize Seller  Barley Freqeuncy  Barley Quantity  \
# 0    Riverside Circuitry Ltd                 1              181
# 1        Tilly Beverages Ltd                 3              882
# 2        Tilly Beverages Ltd                 0                0
# 3                        NaN                 2               91
# 4        Oakes Workshops Ltd                 0                0
# ..                       ...               ...              ...
# 495     Peabody Workwear Ltd                 1              399
# 496  Riverside Circuitry Ltd                 0                0
# 497  Riverside Circuitry Ltd                 0                0
# 498     Peabody Workwear Ltd                 4              770
# 499      Oakes Workshops Ltd                 1              220
#
#                Barley Seller  Distance
# 0       Peabody Workwear Ltd       666
# 1    Riverside Circuitry Ltd       588
# 2                        NaN       295
# 3        Oakes Workshops Ltd       718
# 4                        NaN       404
# ..                       ...       ...
# 495     Peabody Workwear Ltd       766
# 496                      NaN       585
# 497                      NaN       986
# 498  Riverside Circuitry Ltd       614
# 499     Peabody Workwear Ltd       774
#
# [500 rows x 17 columns]

# %%
df.to_csv('customer_data_ver_2.csv', index=False)
