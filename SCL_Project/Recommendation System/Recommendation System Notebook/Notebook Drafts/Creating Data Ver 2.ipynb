# %%
import pandas as pd
import numpy as np

# %%
# %%bash
# git clone https://github.com/kptriescoding/farmer-app-datasets
# Out:
# fatal: destination path 'farmer-app-datasets' already exists and is not an empty directory.

# %%
df_name=pd.read_csv("/content/farmer-app-datasets/Recommendation System/ExportCSV.csv")
df_farmer=pd.read_csv("/content/farmer-app-datasets/Datasets/farmers.csv")["Bates Double Glazing Ltd"]
arr=[];
for i in range(1,501):
  id=str(i)
  while len(id)<3:
    id="0"+id
  arr.append("user_"+id)
df_userId=pd.DataFrame(arr,columns=["uid"])
df_userId
# Out:
#           uid
# 0    user_001
# 1    user_002
# 2    user_003
# 3    user_004
# 4    user_005
# ..        ...
# 495  user_496
# 496  user_497
# 497  user_498
# 498  user_499
# 499  user_500
#
# [500 rows x 1 columns]

# %%
d_farmer=[]
for i in range(1,400):
  d_farmer.append(df_farmer.loc[np.random.randint(0,4)])
d_farmer
# Out:
# ['Peabody Workwear Ltd',
#  'Oakes Workshops Ltd',
#  'Peabody Workwear Ltd',
#  'Tilly Beverages Ltd',
#  'Tilly Beverages Ltd',
#  'Oakes Workshops Ltd',
#  'Tilly Beverages Ltd',
#  'Oakes Workshops Ltd',
#  'Peabody Workwear Ltd',
#  'Riverside Circuitry Ltd',
#  'Riverside Circuitry Ltd',
#  'Tilly Beverages Ltd',
#  'Peabody Workwear Ltd',
#  'Peabody Workwear Ltd',
#  'Tilly Beverages Ltd',
#  'Oakes Workshops Ltd',
#  'Oakes Workshops Ltd',
#  'Peabody Workwear Ltd',
#  'Peabody Workwear Ltd',
#  'Oakes Workshops Ltd',
#  'Tilly Beverages Ltd',
#  'Peabody Workwear Ltd',
#  'Peabody Workwear Ltd',
#  'Peabody Workwear Ltd',
#  'Peabody Workwear Ltd',
#  'Oakes Workshops Ltd',
#  'Oakes Workshops Ltd',
#  'Riverside Circuitry Ltd',
#  'Oakes Workshops Ltd',
#  'Oakes Workshops Ltd',
#  'Peabody Workwear Ltd',
#  'Oakes Workshops Ltd',
#  'Tilly Beverages Ltd',
#  'Riverside Circuitry Ltd',
#  'Riverside Circuitry Ltd',
#  'Riverside Circuitry Ltd',
#  'Tilly Beverages Ltd',
# ...

# %%
d_frequency=np.random.randint(1,7,400)
d_na=np.full(shape=100,fill_value=0)
d_f=np.concatenate([d_frequency,d_na],axis=None)
df=pd.DataFrame(d_f,columns=["Wheat Freqeuncy"]);


d_quan=np.random.randint(1,1000,400)
d_q=np.concatenate([d_quan,d_na],axis=None)
df_q=pd.DataFrame(d_q,columns=["Wheat Quantity"])


np.random.shuffle(d_farmer)
d_ex=np.full(shape=100,fill_value="NA")
df_f=pd.DataFrame(d_farmer,columns=["Wheat Seller"])



df_full=pd.concat([df,df_q,df_f],axis=1)
df_full_wheat=df_full.sample(frac=1)
print(df_full_wheat)
# Out:
#      Wheat Freqeuncy  Wheat Quantity             Wheat Seller
# 197                2             944  Riverside Circuitry Ltd
# 189                6             799  Riverside Circuitry Ltd
# 248                1             465      Oakes Workshops Ltd
# 270                4             931  Riverside Circuitry Ltd
# 305                2             608  Riverside Circuitry Ltd
# ..               ...             ...                      ...
# 111                6             723     Peabody Workwear Ltd
# 293                5             566      Tilly Beverages Ltd
# 203                3             268      Oakes Workshops Ltd
# 158                3             353     Peabody Workwear Ltd
# 374                2             714      Tilly Beverages Ltd
#
# [500 rows x 3 columns]

# %%
d_frequency=np.random.randint(1,7,400)
d_na=np.full(shape=100,fill_value=0)
d_f=np.concatenate([d_frequency,d_na],axis=None)
df=pd.DataFrame(d_f,columns=["Rubber Freqeuncy"]);


d_quan=np.random.randint(1,1000,400)
d_q=np.concatenate([d_quan,d_na],axis=None)
df_q=pd.DataFrame(d_q,columns=["Rubber Quantity"])


np.random.shuffle(d_farmer)
d_ex=np.full(shape=100,fill_value="NA")
df_f=pd.DataFrame(d_farmer,columns=["Rubber Seller"])



df_full=pd.concat([df,df_q,df_f],axis=1)
df_full_rubber=df_full.sample(frac=1)
print(df_full_rubber)
# Out:
#      Rubber Freqeuncy  Rubber Quantity            Rubber Seller
# 295                 2              462      Tilly Beverages Ltd
# 340                 6              882     Peabody Workwear Ltd
# 300                 5              777      Tilly Beverages Ltd
# 21                  5               99  Riverside Circuitry Ltd
# 253                 6              460      Oakes Workshops Ltd
# ..                ...              ...                      ...
# 389                 5              286      Oakes Workshops Ltd
# 332                 1              366     Peabody Workwear Ltd
# 145                 4              596     Peabody Workwear Ltd
# 493                 0                0                      NaN
# 498                 0                0                      NaN
#
# [500 rows x 3 columns]

# %%
d_frequency=np.random.randint(1,7,400)
d_na=np.full(shape=100,fill_value=0)
d_f=np.concatenate([d_frequency,d_na],axis=None)
df=pd.DataFrame(d_f,columns=["Maize Freqeuncy"]);


d_quan=np.random.randint(1,1000,400)
d_q=np.concatenate([d_quan,d_na],axis=None)
df_q=pd.DataFrame(d_q,columns=["Maize Quantity"])


np.random.shuffle(d_farmer)
d_ex=np.full(shape=100,fill_value="NA")
df_f=pd.DataFrame(d_farmer,columns=["Maize Seller"])



df_full=pd.concat([df,df_q,df_f],axis=1)
df_full_maize=df_full.sample(frac=1)
print(df_full_maize)
# Out:
#      Maize Freqeuncy  Maize Quantity             Maize Seller
# 416                0               0                      NaN
# 476                0               0                      NaN
# 252                3             253  Riverside Circuitry Ltd
# 230                2              94     Peabody Workwear Ltd
# 32                 5             759  Riverside Circuitry Ltd
# ..               ...             ...                      ...
# 232                2              43      Oakes Workshops Ltd
# 155                2             856      Oakes Workshops Ltd
# 439                0               0                      NaN
# 92                 5             553      Tilly Beverages Ltd
# 235                5             770      Tilly Beverages Ltd
#
# [500 rows x 3 columns]

# %%
d_frequency=np.random.randint(1,7,400)
d_na=np.full(shape=100,fill_value=0)
d_f=np.concatenate([d_frequency,d_na],axis=None)
df=pd.DataFrame(d_f,columns=["Barley Freqeuncy"]);


d_quan=np.random.randint(1,1000,400)
d_q=np.concatenate([d_quan,d_na],axis=None)
df_q=pd.DataFrame(d_q,columns=["Barley Quantity"])


np.random.shuffle(d_farmer)
d_ex=np.full(shape=100,fill_value="NA")
df_f=pd.DataFrame(d_farmer,columns=["Barley Seller"])



df_full=pd.concat([df,df_q,df_f],axis=1)
df_full_barley=df_full.sample(frac=1)
print(df_full_barley)
# Out:
#      Barley Freqeuncy  Barley Quantity            Barley Seller
# 377                 3              235  Riverside Circuitry Ltd
# 116                 5              742  Riverside Circuitry Ltd
# 125                 4              732      Oakes Workshops Ltd
# 276                 5              193      Tilly Beverages Ltd
# 389                 3              877  Riverside Circuitry Ltd
# ..                ...              ...                      ...
# 228                 2              197      Tilly Beverages Ltd
# 475                 0                0                      NaN
# 394                 1              243      Tilly Beverages Ltd
# 269                 3              362     Peabody Workwear Ltd
# 35                  5              591  Riverside Circuitry Ltd
#
# [500 rows x 3 columns]

# %%
d_frequency=np.random.randint(1,7,400)
d_na=np.full(shape=100,fill_value=0)
d_f=np.concatenate([d_frequency,d_na],axis=None)
df=pd.DataFrame(d_f,columns=["Sugercane Freqeuncy"]);


d_quan=np.random.randint(1,1000,400)
d_q=np.concatenate([d_quan,d_na],axis=None)
df_q=pd.DataFrame(d_q,columns=["Sugercane Quantity"])


np.random.shuffle(d_farmer)
d_ex=np.full(shape=100,fill_value="NA")
df_f=pd.DataFrame(d_farmer,columns=["Sugercane Seller"])



df_full=pd.concat([df,df_q,df_f],axis=1)
df_full_sugarcane=df_full.sample(frac=1)
print(df_full_sugarcane)
# Out:
#      Sugercane Freqeuncy  Sugercane Quantity         Sugercane Seller
# 111                    6                 885      Oakes Workshops Ltd
# 337                    1                 242      Tilly Beverages Ltd
# 475                    0                   0                      NaN
# 90                     6                 479      Tilly Beverages Ltd
# 390                    6                 676      Oakes Workshops Ltd
# ..                   ...                 ...                      ...
# 356                    3                 736  Riverside Circuitry Ltd
# 118                    5                 564     Peabody Workwear Ltd
# 414                    0                   0                      NaN
# 79                     6                 228     Peabody Workwear Ltd
# 383                    2                 362     Peabody Workwear Ltd
#
# [500 rows x 3 columns]

# %%
d_dist=np.random.randint(1,1000,500)
d_dis=np.concatenate(d_dist,axis=None)
df_dis=pd.DataFrame(d_dis,columns=["Distance"])

# %%
df_full_wheat=df_full_wheat.reset_index();
df_full_rubber=df_full_rubber.reset_index();
df_full_maize=df_full_maize.reset_index();
df_full_sugarcane=df_full_sugarcane.reset_index();
df_full_barley=df_full_barley.reset_index();
df_dis.reset_index()
# Out:
#      index  Distance
# 0        0       963
# 1        1       354
# 2        2       368
# 3        3       363
# 4        4       773
# ..     ...       ...
# 495    495       142
# 496    496       431
# 497    497       102
# 498    498       524
# 499    499       710
#
# [500 rows x 2 columns]

# %%
df=pd.concat([df_userId,df_name,df_full_wheat,df_full_sugarcane,df_full_rubber,df_full_maize,df_full_barley,df_dis],axis=1);
df.drop(["index"],inplace=True,axis=1)
print(df)
# Out:
#           uid FirstName LastName  Wheat Freqeuncy  Wheat Quantity  \
# 0    user_001      Hayden Ripley                2             944
# 1    user_002         Lucy Lakey                6             799
# 2    user_003        Daphne Long                1             465
# 3    user_004       Percy Torres                4             931
# 4    user_005  Vanessa Alldridge                2             608
# ..        ...                ...              ...             ...
# 495  user_496       Taylor Vince                6             723
# 496  user_497     Bryce Clarkson                5             566
# 497  user_498        Gina Watson                3             268
# 498  user_499     Martin Poulton                3             353
# 499  user_500      Johnny Palmer                2             714
#
#                 Wheat Seller  Sugercane Freqeuncy  Sugercane Quantity  \
# 0    Riverside Circuitry Ltd                    6                 885
# ...

# %% [markdown]
# # New Section

# %%
df.to_csv('customer_data_ver_2.csv', index=False)
